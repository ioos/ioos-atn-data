# %% [markdown]
# # Working with the atn trajectory template in cdl
#
# 1. Read the cdl file into netCDF
# 1. Create a netCDF file from the cdl.
# 1. Run the netCDF file against the [IOOS compliance checker](https://github.com/ioos/compliance-checker).

# %%
# Bring template in as netCDF4 dataset
import netCDF4
nc = netCDF4.Dataset.fromcdl('../templates/atn_trajectory_template.cdl')

# %%
print(nc.tocdl())
# Out:
# netcdf atn_trajectory_template {
# dimensions:
# 	time = 1 ;
# 	strlen_taxon_name = 1 ;
# 	strlen_taxon_lsid = 1 ;
# 	animal_obs = 1 ;
# variables:
# 	string trajectory ;
# 		trajectory:cf_role = "trajectory_id" ;
# 		trajectory:long_name = "trajectory identifier" ;
# 		trajectory:_Storage = "contiguous" ;
# 	double time(time) ;
# 		time:_FillValue = -9999.9 ;
# 		time:units = "seconds since 1990-01-01 00:00:00Z" ;
# 		time:standard_name = "time" ;
# 		time:axis = "T" ;
# 		time:_CoordinateAxisType = "Time" ;
# 		time:calendar = "" ;
# 		time:long_name = "Time" ;
# 		time:actual_min = "" ;
# 		time:actual_max = "" ;
# 		time:ancillary_variables = "qartod_time_flag qartod_rollup_flag" ;
# 		time:_Storage = "contiguous" ;
# 		time:_Endianness = "little" ;
# 	int z(time) ;
# 		z:_FillValue = -9999 ;
# 		z:axis = "Z" ;
# 		z:long_name = "depth" ;
# 		z:positive = "down" ;
# 		z:standard_name = "depth" ;
# 		z:units = "m" ;
# 		z:actual_min = "" ;
# 		z:actual_max = "" ;
# 		z:instrument = "instrument_pressure" ;
# 		z:platform = "animal" ;
# 		z:_Storage = "contiguous" ;
# 		z:_Endianness = "little" ;
# 	double lat(time) ;
# 		lat:_FillValue = -9999. ;
# 		lat:axis = "Y" ;
# 		lat:_CoordinateAxisType = "Lat" ;
# 		lat:long_name = "Profile location latitude" ;
# 		lat:standard_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:valid_max = 90. ;
# 		lat:valid_min = -90. ;
# 		lat:actual_min = "" ;
# 		lat:actual_max = "" ;
# 		lat:instrument = "instrument_location" ;
# 		lat:platform = "animal" ;
# 		lat:ancillary_variables = "qartod_location_flag qartod_rollup_flag" ;
# 		lat:_Storage = "contiguous" ;
# 		lat:_Endianness = "little" ;
# 	double lon(time) ;
# 		lon:_FillValue = -9999. ;
# 		lon:axis = "X" ;
# 		lon:_CoordinateAxisType = "Lon" ;
# 		lon:long_name = "Profile location longitude" ;
# 		lon:standard_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:valid_max = 180. ;
# 		lon:valid_min = -180. ;
# 		lon:actual_min = "" ;
# 		lon:actual_max = "" ;
# 		lon:instrument = "instrument_location" ;
# 		lon:platform = "animal" ;
# 		lon:ancillary_variables = "qartod_location_flag qartod_rollup_flag" ;
# 		lon:_Storage = "contiguous" ;
# 		lon:_Endianness = "little" ;
# 	string location_class(time) ;
# 		location_class:coordinates = "time z lon lat" ;
# 		location_class:long_name = "Location Quality Code" ;
# 		location_class:standard_name = "status_flag" ;
# 		location_class:comment = "Quality codes from the ARGOS satellite (in meters): G,3,2,1,0,A,B,Z. See http://www.argos-system.org/manual/3-location/34_location_classes.htm" ;
# 		location_class:code_values = "G,3,2,1,0,A,B,Z" ;
# 		location_class:code_meanings = "estimated error less than 100m and 1+ messages received per satellite pass,estimated error less than 250m and 4+ messages received per satellite pass,estimated error between 250m and 500m and 4+ messages per satellite pass,estimated error between 500m and 1500m and 4+ messages per satellite pass,estimated error greater than 1500m and 4+ messages received per satellite pass,no least squares estimated error or unbounded kalman filter estimated error and 3 messages received per satellite pass,no least squares estimated error or unbounded kalman filter estimated error and 1 or 2 messages received per satellite pass,invalid location (available for Service Plus or Auxilliary Location Processing)" ;
# 		location_class:instrument = "instrument_location" ;
# 		location_class:platform = "animal" ;
# 		location_class:ancillary_variables = "qartod_location_flag qartod_rollup_flag" ;
# 		location_class:_Storage = "contiguous" ;
# 	double ellipse_orientation(time) ;
# 		ellipse_orientation:_FillValue = -9999.9 ;
# 		ellipse_orientation:coordinates = "time z lon lat" ;
# 		ellipse_orientation:long_name = "Ellipse orientation" ;
# 		ellipse_orientation:units = "degrees" ;
# 		ellipse_orientation:comment = "The angle in degrees of the ellipse from true north, proceeding clockwise (0 to 360). A blank field represents 0 degrees." ;
# 		ellipse_orientation:instrument = "instrument_location" ;
# 		ellipse_orientation:platform = "animal" ;
# 		ellipse_orientation:_Storage = "contiguous" ;
# 		ellipse_orientation:_Endianness = "little" ;
# 	double error_radius(time) ;
# 		error_radius:_FillValue = -9999.9 ;
# 		error_radius:coordinates = "time z lon lat" ;
# 		error_radius:long_name = "Error radius" ;
# 		error_radius:units = "m" ;
# 		error_radius:comment = "If the position is best represented as a circle, this field gives the radius of that circle in meters." ;
# 		error_radius:instrument = "instrument_location" ;
# 		error_radius:platform = "animal" ;
# 		error_radius:_Storage = "contiguous" ;
# 		error_radius:_Endianness = "little" ;
# 	double semi_major_axis(time) ;
# 		semi_major_axis:_FillValue = -9999.9 ;
# 		semi_major_axis:coordinates = "time z lon lat" ;
# 		semi_major_axis:long_name = "Error semi-major axis" ;
# 		semi_major_axis:units = "m" ;
# 		semi_major_axis:comment = "If the estimated position error is best expressed as an ellipse, this field gives the length in meters of the semi-major elliptical axis (one half of the major axis)." ;
# 		semi_major_axis:instrument = "instrument_location" ;
# 		semi_major_axis:platform = "animal" ;
# 		semi_major_axis:_Storage = "contiguous" ;
# 		semi_major_axis:_Endianness = "little" ;
# 	double semi_minor_axis(time) ;
# 		semi_minor_axis:_FillValue = -9999.9 ;
# 		semi_minor_axis:coordinates = "time z lon lat" ;
# 		semi_minor_axis:long_name = "Error semi-minor axis" ;
# 		semi_minor_axis:units = "m" ;
# 		semi_minor_axis:comment = "If the estimated position error is best expressed as an ellipse, this field gives the length in meters of the semi-minor elliptical axis (one half of the minor axis)." ;
# 		semi_minor_axis:instrument = "instrument_location" ;
# 		semi_minor_axis:platform = "animal" ;
# 		semi_minor_axis:_Storage = "contiguous" ;
# 		semi_minor_axis:_Endianness = "little" ;
# 	double offset(time) ;
# 		offset:_FillValue = -9999.9 ;
# 		offset:coordinates = "time z lon lat" ;
# 		offset:long_name = "Offset" ;
# 		offset:units = "m" ;
# 		offset:comment = "This field is non-zero if the circle or ellipse are not centered on the (Latitude, Longitude) values on this row. \"Offset\" gives the distance in meters from (Latitude, Longitude) to the center of the ellipse." ;
# 		offset:instrument = "instrument_location" ;
# 		offset:platform = "platform" ;
# 		offset:_Storage = "contiguous" ;
# 		offset:_Endianness = "little" ;
# 	double offset_orientation(time) ;
# 		offset_orientation:_FillValue = -9999.9 ;
# 		offset_orientation:coordinates = "time z lon lat" ;
# 		offset_orientation:long_name = "Offset orientation" ;
# 		offset_orientation:units = "degrees" ;
# 		offset_orientation:comment = "If the \"Offset\" field is non-zero, this field is the angle in degrees from (Latitude, Longitude) to the center of the ellipse. Zero degrees is true north; a blank field represents 0 degrees." ;
# 		offset_orientation:instrument = "instrument_location" ;
# 		offset_orientation:platform = "platform" ;
# 		offset_orientation:_Storage = "contiguous" ;
# 		offset_orientation:_Endianness = "little" ;
# 	int64 qartod_rollup_flag(time) ;
# 		qartod_rollup_flag:_FillValue = 0LL ;
# 		qartod_rollup_flag:flag_meanings = "PASS NOT_EVALUATED SUSPECT FAIL MISSING" ;
# 		qartod_rollup_flag:flag_values = "1, 2, 3, 4, 9" ;
# 		qartod_rollup_flag:long_name = "" ;
# 		qartod_rollup_flag:standard_name = "aggregate_quality_flag" ;
# 		qartod_rollup_flag:references = "" ;
# 		qartod_rollup_flag:_Storage = "contiguous" ;
# 		qartod_rollup_flag:_Endianness = "little" ;
# 	int64 qartod_speed_flag(time) ;
# 		qartod_speed_flag:_FillValue = 0LL ;
# 		qartod_speed_flag:flag_meanings = "PASS NOT_EVALUATED SUSPECT FAIL MISSING" ;
# 		qartod_speed_flag:flag_values = "1, 2, 3, 4, 9" ;
# 		qartod_speed_flag:long_name = "" ;
# 		qartod_speed_flag:standard_name = "gross_range_test_quality_flag" ;
# 		qartod_speed_flag:references = "" ;
# 		qartod_speed_flag:_Storage = "contiguous" ;
# 		qartod_speed_flag:_Endianness = "little" ;
# 	int64 qartod_location_flag(time) ;
# 		qartod_location_flag:_FillValue = 0LL ;
# 		qartod_location_flag:flag_meanings = "PASS NOT_EVALUATED SUSPECT FAIL MISSING" ;
# 		qartod_location_flag:flag_values = "1, 2, 3, 4, 9" ;
# 		qartod_location_flag:long_name = "" ;
# 		qartod_location_flag:standard_name = "location_test_quality_flag" ;
# 		qartod_location_flag:references = "" ;
# 		qartod_location_flag:_Storage = "contiguous" ;
# 		qartod_location_flag:_Endianness = "little" ;
# 	int64 qartod_time_flag(time) ;
# 		qartod_time_flag:_FillValue = 0LL ;
# 		qartod_time_flag:flag_meanings = "PASS NOT_EVALUATED SUSPECT FAIL MISSING" ;
# 		qartod_time_flag:flag_values = "1, 2, 3, 4, 9" ;
# 		qartod_time_flag:long_name = "" ;
# 		qartod_time_flag:standard_name = "gross_range_test_quality_flag" ;
# 		qartod_time_flag:references = "" ;
# 		qartod_time_flag:_Storage = "contiguous" ;
# 		qartod_time_flag:_Endianness = "little" ;
# 	string taxon_name(strlen_taxon_name) ;
# 		taxon_name:standard_name = "biological_taxon_name" ;
# 		taxon_name:long_name = "" ;
# 		taxon_name:_Storage = "contiguous" ;
# 	string taxon_lsid(strlen_taxon_lsid) ;
# 		taxon_lsid:standard_name = "biological_taxon_lsid" ;
# 		taxon_lsid:long_name = "Taxon identifier" ;
# 		taxon_lsid:source = "" ;
# 		taxon_lsid:_Storage = "contiguous" ;
# 	string instrument_tag ;
# 		instrument_tag:long_name = "" ;
# 		instrument_tag:comment = "" ;
# 		instrument_tag:manufacturer = "" ;
# 		instrument_tag:make_model = "" ;
# 		instrument_tag:calibration_date = "" ;
# 		instrument_tag:serial_number = "" ;
# 		instrument_tag:_Storage = "contiguous" ;
# 	string instrument_location ;
# 		instrument_location:long_name = "" ;
# 		instrument_location:location_type = "" ;
# 		instrument_location:comment = "" ;
# 		instrument_location:manufacturer = "" ;
# 		instrument_location:make_model = "" ;
# 		instrument_location:calibration_date = "" ;
# 		instrument_location:serial_number = "" ;
# 		instrument_location:_Storage = "contiguous" ;
# 	string instrument_pressure ;
# 		instrument_pressure:long_name = "" ;
# 		instrument_pressure:comment = "" ;
# 		instrument_pressure:manufacturer = "" ;
# 		instrument_pressure:make_model = "" ;
# 		instrument_pressure:calibration_date = "" ;
# 		instrument_pressure:serial_number = "" ;
# 		instrument_pressure:_Storage = "contiguous" ;
# 	string animal ;
# 		animal:long_name = "" ;
# 		animal:valid_name = "" ;
# 		animal:AphiaID = "" ;
# 		animal:scientificname = "" ;
# 		animal:authority = "" ;
# 		animal:kingdom = "" ;
# 		animal:phylum = "" ;
# 		animal:class = "" ;
# 		animal:order = "" ;
# 		animal:family = "" ;
# 		animal:genus = "" ;
# 		animal:rank = "" ;
# 		animal:superdomain = "" ;
# 		animal:subphylum = "" ;
# 		animal:superclass = "" ;
# 		animal:subclass = "" ;
# 		animal:suborder = "" ;
# 		animal:infraorder = "" ;
# 		animal:species = "" ;
# 		animal:taxonRankID = "" ;
# 		animal:_Storage = "contiguous" ;
# 	double animal_length(animal_obs) ;
# 		animal_length:units = "m" ;
# 		animal_length:long_name = "length of the animal" ;
# 		animal_length:_Storage = "contiguous" ;
# 		animal_length:_Endianness = "little" ;
# 	double animal_weight(animal_obs) ;
# 		animal_weight:units = "kg" ;
# 		animal_weight:long_name = "weight of the animal" ;
# 		animal_weight:_Storage = "contiguous" ;
# 		animal_weight:_Endianness = "little" ;
# 	string animal_sex(animal_obs) ;
# 		animal_sex:long_name = "sex of the animal (m=male, f=female)" ;
# 		animal_sex:_Storage = "contiguous" ;
# 	string animal_stage(animal_obs) ;
# 		animal_stage:long_name = "stage of the animal (adult, juvenile)" ;
# 		animal_stage:_Storage = "contiguous" ;
# 	int crs ;
# 		crs:epsg_code = "EPSG:4326" ;
# 		crs:grid_mapping_name = "latitude_longitude" ;
# 		crs:inverse_flattening = 298.257223563 ;
# 		crs:ioos_category = "Other" ;
# 		crs:long_name = "http://www.opengis.net/def/crs/EPSG/0/4326" ;
# 		crs:semi_major_axis = 6378137. ;
# 		crs:_Storage = "contiguous" ;
# 		crs:_Endianness = "little" ;
#
# // global attributes:
# 		:argos_program_number = "" ;
# 		:acknowledgement = "" ;
# 		:cdm_data_type = "Trajectory" ;
# 		:comment = "" ;
# 		:common_name = "" ;
# 		:contributor_email = "" ;
# 		:contributor_name = "" ;
# 		:contributor_role = "" ;
# 		:contributor_role_vocabulary = "" ;
# 		:Conventions = "CF-1.6, ACDD-1.3, IOOS-1.2" ;
# 		:creator_address = "" ;
# 		:creator_city = "" ;
# 		:creator_country = "" ;
# 		:creator_email = "" ;
# 		:creator_institution = "" ;
# 		:creator_name = "" ;
# 		:creator_phone = "" ;
# 		:creator_sector = "" ;
# 		:creator_type = "" ;
# 		:creator_url = "" ;
# 		:date_created = "" ;
# 		:date_issued = "" ;
# 		:date_modified = "" ;
# 		:date_metadata_modified = "" ;
# 		:featureType = "trajectory" ;
# 		:first_uplink_date = "" ;
# 		:geospatial_bbox = "" ;
# 		:geospatial_bounds_vertical_crs = "" ;
# 		:geospatial_lat_units = "degrees_north" ;
# 		:geospatial_lon_units = "degrees_east" ;
# 		:geospatial_vertical_positive = "down" ;
# 		:geospatial_bounds = "" ;
# 		:geospatial_bounds_crs = "" ;
# 		:geospatial_vertical_units = "m" ;
# 		:geospatial_lat_min = "" ;
# 		:geospatial_lat_max = "" ;
# 		:geospatial_lat_resolution = "" ;
# 		:geospatial_lon_min = "" ;
# 		:geospatial_lon_max = "" ;
# 		:geospatial_lon_resolution = "" ;
# 		:geospatial_vertical_min = "" ;
# 		:geospatial_vertical_max = "" ;
# 		:geospatial_vertical_resolution = "" ;
# 		:history = "" ;
# 		:id = "" ;
# 		:infoUrl = "" ;
# 		:institution = "" ;
# 		:instrument = "" ;
# 		:keywords = "EARTH SCIENCE > BIOLOGICAL CLASSIFICATION > ANIMALS/INVERTEBRATES" ;
# 		:keywords_vocabulary = "GCMD Earth Science Keywords. Version 10.0" ;
# 		:naming_authority = "" ;
# 		:ncei_template_version = "NCEI_NetCDF_Trajectory_Template_v2.0" ;
# 		:publisher_email = "" ;
# 		:publisher_name = "" ;
# 		:publisher_url = "" ;
# 		:source = "" ;
# 		:standard_name_vocabulary = "CF Standard Name Table v78" ;
# 		:time_coverage_start = "" ;
# 		:time_coverage_end = "" ;
# 		:time_coverage_duration = "" ;
# 		:time_coverage_resolution = "" ;
# 		:last_uplink_date = "" ;
# 		:last_location_lat = "" ;
# 		:last_location_lon = "" ;
# 		:last_location_date = "" ;
# 		:license = "" ;
# 		:metadata_link = "" ;
# 		:NCO = "" ;
# 		:processing_level = "" ;
# 		:project = "" ;
# 		:platform = "animal" ;
# 		:platform_id = "" ;
# 		:platform_name = "" ;
# 		:platform_vocabulary = "" ;
# 		:program = "" ;
# 		:ptt = "" ;
# 		:publisher_country = "" ;
# 		:publisher_institution = "" ;
# 		:publisher_type = "" ;
# 		:sea_name = "" ;
# 		:summary = "This is a template file for the IOOS Animal Telemetry Network (ATN) trajectory observations." ;
# 		:title = "Animal Telemetry Network trajectory netCDF file template" ;
# 		:uuid = "" ;
# 		:vendor = "" ;
# 		:vendor_id = "" ;
# 		:wmo_platform_code = "" ;
# 		:_NCProperties = "version=2,netcdf=4.7.4,hdf5=1.10.6" ;
# 		:_SuperblockVersion = 0 ;
# 		:_IsNetcdf4 = 1 ;
# 		:_Format = "netCDF-4" ;
# }

# %%
#generate netCDF file from cdl text document
# !ncgen -o ../templates/atn_trajectory_template.nc ../templates/atn_trajectory_template.cdl

# %% [markdown]
# ## Run compliance checker on the template netCDF file

# %%
import compliance_checker

print(compliance_checker.__version__)
# Out:
# 4.3.4

# %%
# First import the compliance checker and test that it is installed properly.
from compliance_checker.runner import CheckSuite, ComplianceChecker

# Load all available checker classes.
check_suite = CheckSuite()
check_suite.load_all_available_checkers()

# %%
output_file = "../templates/atn_traj_template_CC.txt"

return_value, errors = ComplianceChecker.run_checker(
    ds_loc='../templates/atn_trajectory_template.nc',
    checker_names=["cf", "acdd", "ncei-trajectory:latest", "ioos-glider"],
    verbose=True,
    criteria="normal",
    skip_checks=None,
    output_filename=output_file,
    output_format="text",
)
# Out:
# Using cached standard name table v78 from C:\Users\Mathew.Biddle\.local\share\compliance-checker\cf-standard-name-table-test-78.xml

# %%
with open(output_file, "r") as f:
    print(f.read())
# Out:
# --------------------------------------------------------------------------------
#                          IOOS Compliance Checker Report
#                                  Version 4.3.4
#                      Report generated 2021-09-21T13:52:38Z
#                               ncei-trajectory:2.0
#    http://www.nodc.noaa.gov/data/formats/netcdf/v2.0/trajectoryIncomplete.cdl
# --------------------------------------------------------------------------------
#                                Corrective Actions
# atn_trajectory_template.nc has 11 potential issues
#
#
#                                 Medium Priority
# --------------------------------------------------------------------------------
# Recommended attributes for coordinate variable z
# * valid_min attribute should exist, have the same type as z, and not be empty or valid_range should be defined
# * valid_max attribute should exist, have the same type as z, and not be empty or valid_range should be defined
#
# Recommended attributes for flag variable qartod_location_flag
# * The standard_name attribute should end with status_flag
# * The long_name attribute should exist and not be empty
#
# Recommended attributes for flag variable qartod_rollup_flag
# * The standard_name attribute should end with status_flag
# * The long_name attribute should exist and not be empty
#
# Recommended attributes for flag variable qartod_speed_flag
# * The standard_name attribute should end with status_flag
# * The long_name attribute should exist and not be empty
#
# Recommended attributes for flag variable qartod_time_flag
# * The standard_name attribute should end with status_flag
# * The long_name attribute should exist and not be empty
#
# Recommended attributes for instrument variable instrument_location
# * comment attribute should not be empty if specified
# * long_name attribute should exist and not be empty
#
# Recommended attributes for instrument variable instrument_pressure
# * comment attribute should not be empty if specified
# * long_name attribute should exist and not be empty
#
# Recommended attributes for platform variable animal
# * At least one attribute should be defined to identify the platform: ncei_code, wmo_code, imo_code, call_sign.
# * long_name attribute should exist and not be empty
#
# Recommended attributes for variable lat
# * comment attribute should exist and not be empty
#
# Recommended global attributes
# * acknowledgement attribute should exist and not be empty
# * creator_name should exist and not be empty.
# * creator_url should exist and not be empty.
# * creator_email should exist and not be empty.
# * comment attribute should not be empty if specified
# * date_created should exist and be ISO-8601 format (example: PT1M30S), currently:
# * date_modified should exist and be ISO-8601 format (example: PT1M30S), currently:
# * geospatial_lat_min should exist and not be empty.
# * geospatial_lat_max should exist and not be empty.
# * geospatial_lon_min should exist and not be empty.
# * geospatial_lon_max should exist and not be empty.
# * geospatial_vertical_max should exist and not be empty.
# * geospatial_vertical_min should exist and not be empty.
# * geospatial_bounds should exist and not be empty.
# * geospatial_bounds_crs should exist and not be empty.
# * geospatial_bounds_vertical_crs should exist and not be empty.
# * history should exist and not be empty.
# * id should exist and not be empty.
# * institution should exist and not be empty.
# * license should exist and not be empty.
# * naming_authority should exist and not be empty.
# * project should exist and not be empty.
# * processing_level should exist and not be empty.
# * publisher_name should exist and not be empty.
# * publisher_email should exist and not be empty.
# * publisher_url should exist and not be empty.
# * source should exist and not be empty.
# * time_coverage_duration should exist and be ISO-8601 format (example: PT1M30S), currently:
# * time_coverage_resolution should exist and be ISO-8601 format (example: PT1M30S), currently:
# * time_coverage_start should exist and be ISO-8601 format (example: PT1M30S), currently:
# * time_coverage_end should exist and be ISO-8601 format (example: PT1M30S), currently:
# * uuid should exist and not be empty.
#
# Recommended variable for grid mapping should exist
# * A variable to describe the grid mapping should exist
#
#
# --------------------------------------------------------------------------------
#                          IOOS Compliance Checker Report
#                                  Version 4.3.4
#                      Report generated 2021-09-21T13:52:38Z
#                                      cf:1.7
# http://cfconventions.org/Data/cf-conventions/cf-conventions-1.7/cf-conventions.html
# --------------------------------------------------------------------------------
#                                Corrective Actions
# atn_trajectory_template.nc has 3 potential issues
#
#
#                                      Errors
# --------------------------------------------------------------------------------
# Â§2.2 Data Types
# * The variable qartod_rollup_flag failed because the datatype is int64
# * The variable qartod_speed_flag failed because the datatype is int64
# * The variable qartod_location_flag failed because the datatype is int64
# * The variable qartod_time_flag failed because the datatype is int64
#
# Â§3.5 Flags
# * location_class does not define either flag_masks or flag_values
# * location_class's flag_meanings attribute is required for flag variables
# * location_class's flag_meanings attribute must be a string
# * qartod_rollup_flag's flag_values must be an array of values not <class 'str'>
# * qartod_speed_flag's flag_values must be an array of values not <class 'str'>
# * qartod_location_flag's flag_values must be an array of values not <class 'str'>
# * qartod_time_flag's flag_values must be an array of values not <class 'str'>
#
#
#                                     Warnings
# --------------------------------------------------------------------------------
# Â§2.6 Attributes
# * Â§2.6.2 global attribute history should exist and be a non-empty string
# * Â§2.6.2 qartod_rollup_flag:references should be a non-empty string
# * Â§2.6.2 qartod_speed_flag:references should be a non-empty string
# * Â§2.6.2 qartod_location_flag:references should be a non-empty string
# * Â§2.6.2 qartod_time_flag:references should be a non-empty string
# * Â§2.6.2 taxon_lsid:source should be a non-empty string
# * Â§2.6.2 instrument_tag:comment should be a non-empty string
# * Â§2.6.2 instrument_location:comment should be a non-empty string
# * Â§2.6.2 instrument_pressure:comment should be a non-empty string
# * Â§2.6.2 comment global attribute should be a non-empty string
# * Â§2.6.2 institution global attribute should be a non-empty string
# * Â§2.6.2 source global attribute should be a non-empty string
# * Â§2.6.1 Conventions global attribute does not contain "CF-1.7"
#
#
# --------------------------------------------------------------------------------
#                          IOOS Compliance Checker Report
#                                  Version 4.3.4
#                      Report generated 2021-09-21T13:52:38Z
#                                     acdd:1.3
# http://wiki.esipfed.org/index.php?title=Category:Attribute_Conventions_Dataset_Discovery
# --------------------------------------------------------------------------------
#                                Corrective Actions
# atn_trajectory_template.nc has 14 potential issues
#
#
#                                Highly Recommended
# --------------------------------------------------------------------------------
# variable "animal_length" missing the following attributes:
# * coverage_content_type
# * standard_name
#
# variable "animal_weight" missing the following attributes:
# * coverage_content_type
# * standard_name
#
# variable "ellipse_orientation" missing the following attributes:
# * coverage_content_type
# * standard_name
#
# variable "error_radius" missing the following attributes:
# * coverage_content_type
# * standard_name
#
# variable "offset" missing the following attributes:
# * coverage_content_type
# * standard_name
#
# variable "offset_orientation" missing the following attributes:
# * coverage_content_type
# * standard_name
#
# variable "semi_major_axis" missing the following attributes:
# * coverage_content_type
# * standard_name
#
# variable "semi_minor_axis" missing the following attributes:
# * coverage_content_type
# * standard_name
#
#
#                                   Recommended
# --------------------------------------------------------------------------------
# Global Attributes
# * Could not parse WKT from geospatial_bounds, possible bad value: ""
# * comment is empty or completely whitespace
# * creator_name is empty or completely whitespace
# * creator_url is empty or completely whitespace
# * creator_email is empty or completely whitespace
# * geospatial_lat_min is empty or completely whitespace
# * geospatial_lat_max is empty or completely whitespace
# * geospatial_lon_min is empty or completely whitespace
# * geospatial_lon_max is empty or completely whitespace
# * geospatial_vertical_min is empty or completely whitespace
# * geospatial_vertical_max is empty or completely whitespace
# * geospatial_bounds_crs is empty or completely whitespace
# * geospatial_bounds_vertical_crs is empty or completely whitespace
# * history is empty or completely whitespace
# * id is empty or completely whitespace
# * institution is empty or completely whitespace
# * license is empty or completely whitespace
# * naming_authority is empty or completely whitespace
# * project is empty or completely whitespace
# * processing_level is empty or completely whitespace
# * publisher_name is empty or completely whitespace
# * publisher_url is empty or completely whitespace
# * publisher_email is empty or completely whitespace
# * source is empty or completely whitespace
# * time_coverage_start is empty or completely whitespace
# * time_coverage_end is empty or completely whitespace
# * time_coverage_duration is empty or completely whitespace
# * time_coverage_resolution is empty or completely whitespace
#
# date_created_is_iso
# * Datetime provided is not in a valid ISO 8601 format
#
# geospatial_lat_extents_match
# * Could not convert one of geospatial_lat_min () or max () to float see CF-1.6 spec chapter 4.1
#
# geospatial_lon_extents_match
# * Could not convert one of geospatial_lon_min () or max () to float see CF-1.6 spec chapter 4.1
#
# geospatial_vertical_extents_match
# * geospatial_vertical_min cannot be cast to float
# * geospatial_vertical_max cannot be cast to float
#
# time_coverage_extents_match
# * time_coverage attributes are not formatted properly. Use the ISO 8601:2004 date format, preferably the extended format.
